# %%
# If gspx is not installed, we add it to the path
import os, sys
gdir = os.path.dirname(os.getcwd())  # parent folder
sys.path.insert(0, gdir)

# %%
from gspx.datasets import uk_wind
import networkx as nx
from gspx.utils.graph import nearest_neighbors

df = uk_wind()
coords = df[['LONGITUDE', 'LATITUDE']].to_numpy()
A = nearest_neighbors(
    df[['LATITUDE', 'LONGITUDE']].to_numpy(),
    n_neighbors=10).todense()

# %%
df
# Out:
#                                 TOWN   LATITUDE  LONGITUDE  WIND_SPEED  \
# 0            Troon, Scotland, the UK  55.540001  -4.660000        3.09
# 1            St.Asaph, Wales, the UK  53.257999  -3.442000        1.33
# 2             Stirling, Scotland, UK  56.116600  -3.936900        1.96
# 3    Welling, Bexley, London, the UK  51.456600   0.105600        6.17
# 4          Bonnybridge, Scotland, UK  56.003227  -3.888634        1.96
# ..                               ...        ...        ...         ...
# 172  Newport, Telford and Wrekin, UK  52.768555  -2.375587        3.57
# 173                  Dover, Kent, UK  51.126369   1.316198        5.19
# 174                     Limavady, UK  55.051434  -6.950054        4.94
# 175             Litcham, Norfolk, UK  52.724182   0.791488        3.61
# 176            Weybridge, Surrey, UK  51.371628  -0.457904        4.63
#
#      WIND_DEGREES
# 0             210
# 1             116
# 2             202
# 3              90
# 4             196
# ..            ...
# 172           158
# 173            63
# 174           164
# 175           128
# 176            90
#
# [177 rows x 5 columns]

# %%
G = nx.Graph(A)

# %%
import matplotlib.pyplot as plt

pos = df[['LONGITUDE', 'LATITUDE']].to_numpy()

plt.figure(figsize=(5, 10))
nx.draw(G, pos=pos, node_size=20, edge_color=(0.8, 0.8, 0.8, 0.3)) # node_color=color_map, with_labels=True)
